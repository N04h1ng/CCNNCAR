# %%
import matplotlib.pyplot as plt
from scipy import io

# %%
aetadavgloss = io.loadmat('D:/code/machine learning/CCNNCAR/cloud/aetadavgtloss.mat')
aetadmixavgloss = io.loadmat('D:/code/machine learning/CCNNCAR/cloud/aetadmixavgtloss.mat')
caetadavgloss = io.loadmat('D:/code/machine learning/CCNNCAR/cloud/caetadavgtloss.mat')
caetadmix1avgloss = io.loadmat('D:/code/machine learning/CCNNCAR/cloud/caetadmixavgtloss.mat')

# %%
train_num = len(aetadavgloss['avgtloss'][0])
train_index = []
for i in range(train_num):
    train_index.append(i)

# %%
# %matplotlib inline
plt.plot(train_index, aetadavgloss['avgtloss'][0])
plt.plot(train_index, aetadmixavgloss['avgtloss'][0])
plt.plot(train_index, caetadavgloss['avgtloss'][0])
plt.plot(train_index, caetadmixavgloss['avgtloss'][0])

plt.ylim(0.0005,0.004)
#plt.xticks(train_index)
plt.legend(['aetad','aetadmix','caetad','caetadmix'], loc = 'upper right')
plt.xlabel('epoch')
plt.ylabel('train_loss')
# Out:
# Text(0, 0.5, 'train_loss')
